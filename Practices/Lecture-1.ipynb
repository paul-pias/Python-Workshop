# %% [markdown]
# # String

# %%
a = "Hey"
b = "Hey there!"
c = "742 Evergreen Terrace"
d = "1234"
e = "'How long is a piece of string?' he asked"
f = "'!$*#@ you!' she replied"

# %%
a = "Hey"
print(len(a))
p = "1hd"
p.capitalize()
# Out:
# 3
# '1hd'

# %%
x = "abc"
print(x[:1])
# Out:
# a

# %%
print(1+2)
print("1"+"2")
# Out:
# 3
# 12

# %%
a = "picP\t123 "
b = "21344"
print(a.capitalize())  # Capitalize the first character of the string
print(a.title())      # Capitalize the first character of every word on that string
print(a.isdigit())
print(a.center(15))  # Add spaces before the string
print(a.encode())  # Convert it to bytecode
print("Find :", a.find('p'))  # Find the first occurance of p
print("Right Find :", a.rfind('p')) # Find the first occurance of p from the right side
print("Count : ", a.count("p")) # Count the occurance of p
print(",".join(a))  # Join each value with a comma
print("Lower :" ,a.lower())
print("Upper :" ,a.upper())
print(b.endswith("4")) # Check the condition and returns a bool value
print("Space : ", a.isspace())

a = "bee" 
b = a.center(12, "-")
print(b)

print (a.isnumeric())
print (b.isnumeric())
# Out:
# Picp	123
# Picp	123
# False
#    picP	123
# b'picP\t123 '
# Find : 0
# Right Find : 0
# Count :  1
# p,i,c,P,	,1,2,3,
# Lower : picp	123
# Upper : PICP	123
# True
# Space :  False
# ----bee-----
# False
# False

# %%
e = "Once again he asked \"How long  is a piece of string?\""
# print(e)
",".join(e)
# Out:
# 'O,n,c,e, ,a,g,a,i,n, ,h,e, ,a,s,k,e,d, ,",H,o,w, ,l,o,n,g, , ,i,s, ,a, ,p,i,e,c,e, ,o,f, ,s,t,r,i,n,g,?,"'

# %% [markdown]
# Escape Sequence

# %%
msg = "ATTENTION!\nFor those about to rock, we salute you!"
print(msg)
# Out:
# ATTENTION!
# For those about to rock, we salute you!

# %% [markdown]
# # Triple Quotes

# %% [markdown]
# msg = """This string
# spans
# multiple lines"""
# print(msg)
#
# msg = '''This string
# spans
# multiple lines'''
# print(msg)

# %%
planet = "Jupiter"
print(planet[2])

# %% [markdown]
# # String Formatting Operator

# %%
print("Hello %s, you scored %i out of %.3f" % ("Homer", 3, 100.00))
# Out:
# Hello Homer, you scored 3 out of 100.000

# %%
with open("test.txt",'w',encoding = 'utf-8') as f:
    f.write("my first file\n")
    f.write("This file\n\n")
    f.write("contains three lines\n")

x = 10
x /= 5
print(x)

# %%
# The current volume of a water reservoir (in cubic metres)
reservoir_volume = 4.445e8
# The amount of rainfall from a storm (in cubic metres)
rainfall = 5e6

# decrease the rainfall variable by 10% to account for runoff
rainfall =

# add the rainfall variable to the reservoir_volume variable
reservoir_volume 

# increase reservoir_volume by 5% to account for stormwater that flows into the reservoir in the days following the storm
reservoir_volume+=reservoir_volume*.05


# decrease reservoir_volume by 5% to account for evaporation
reservoir_volume =

# subtract 2.5e5 cubic metres from reservoir_volume to account for water that's piped to arid regions.
reservoir_volume = 

# print the new value of the reservoir_volume variable
print(reservoir_volume)

# %%
with open("movie_Information.txt",'r') as f:
    movies = f.read()
    with open ("Actors_Information.txt",'w') as m:
#         print(movies)
#         m.write(movies)
#          print(movies.split(":"))
        
        for movie in movies:
            print(movie.split(":")[0])
#             actor_name = (movie.split(":")[2])
#             movie_name = (movie.split(":")[0])
#             m.write(actor_name.strip() + " : " + movie_name.strip() + '\n')
# Out:
# B
# r
# a
# v
# e
# h
# e
# a
# r
# t
#
#
#
# M
# e
# l
#
# G
# i
# b
# s
# o
# n
#
#
#
# M
# e
# l
#
# G
# i
# b
# s
# o
# n
#
#
#
# 1
# 9
# 9
# 5
#
#
#
# $
# 7
# 5
# .
# 6
# 0
# M
#
#
# T
# h
# e
#
# T
# e
# r
# m
# i
# n
# a
# l
#
#
#
# S
# t
# e
# v
# e
# n
#
# S
# p
# i
# e
# l
# b
# e
# r
# g
#
#
#
# T
# o
# m
#
# H
# a
# n
# k
# s
#
#
#
# 2
# 0
# 0
# 4
#
#
#
# $
# 7
# 7
# .
# 8
# 7
# M
#
#
# T
# h
# e
#
# G
# r
# e
# e
# n
#
# M
# i
# l
# e
#
#
#
# F
# r
# a
# n
# k
#
# D
# a
# r
# a
# b
# o
# n
# t
#
#
#
# T
# o
# m
#
# H
# a
# n
# k
# s
#
#
#
# 1
# 9
# 9
# 9
#
#
#
# $
# 1
# 3
# 6
# .
# 8
# 0
# M
#
#
# T
# h
# e
#
# H
# a
# t
# e
# f
# u
# l
#
# E
# i
# g
# h
# t
#
#
#
# Q
# u
# e
# n
# t
# i
# n
#
# T
# a
# r
# a
# n
# t
# i
# n
# o
#
#
#
# S
# a
# m
# u
# e
# l
#
# L
# .
#
# J
# a
# c
# k
# s
# o
# n
#
#
#
# 2
# 0
# 1
# 5
#
#
#
# $
# 1
# 5
# 5
# .
# 8
# M
#
#
# T
# h
# e
#
# G
# o
# d
# f
# a
# t
# h
# e
# r
#
#
#
# F
# r
# a
# n
# c
# i
# s
#
# F
# o
# r
# d
#
# C
# o
# p
# p
# o
# l
# a
#
#
#
# A
# l
#
# P
# a
# c
# i
# n
# o
#
#
#
# 1
# 9
# 7
# 2
#
#
#
# $
# 1
# 3
# 4
# .
# 9
# 7
# M
#
#
# T
# h
# e
#
# S
# h
# a
# w
# s
# h
# a
# n
# k
#
# R
# e
# d
# e
# m
# p
# t
# i
# o
# n
#
#
#
# F
# r
# a
# n
# k
#
# D
# a
# r
# a
# b
# o
# n
# t
#
#
#
# M
# o
# r
# g
# a
# n
#
# F
# r
# e
# e
# m
# a
# n
#
#
#
# 1
# 9
# 9
# 4
#
#
#
# $
# 2
# 8
# .
# 3
# 4
# M
#
#
# S
# c
# h
# i
# n
# d
# l
# e
# r
# '
# s
#
# L
# i
# s
# t
#
#
#
# S
# t
# e
# v
# e
# n
#
# S
# p
# i
# e
# l
# b
# e
# r
# g
#
#
#
# L
# i
# a
# m
#
# N
# e
# e
# s
# o
# n
#
#
#
# 1
# 9
# 9
# 3
#
#
#
# $
# 9
# 6
# .
# 0
# 7
# M
#
#
# V
# e
# r
# t
# i
# g
# o
#
#
#
# A
# l
# f
# r
# e
# d
#
# H
# i
# t
# c
# h
# c
# o
# c
# k
#
#
#
# J
# a
# m
# e
# s
#
# S
# t
# e
# w
# a
# r
# t
#
#
#
# 1
# 9
# 5
# 8
#
#
#
# $
# 3
# .
# 2
# 0
# M
#
#
# F
# o
# r
# r
# e
# s
# t
#
# G
# u
# m
# p
#
#
#
# R
# o
# b
# e
# r
# t
#
# Z
# e
# m
# e
# c
# k
# i
# s
#
#
#
# T
# o
# m
#
# H
# a
# n
# k
# s
#
#
#
# 1
# 9
# 9
# 4
#
#
#
# $
# 3
# 3
# 0
# .
# 2
# 5
# M
#
#
# 1
# 2
#
# A
# n
# g
# r
# y
#
# M
# e
# n
#
#
#
# S
# i
# d
# n
# e
# y
#
# L
# u
# m
# e
# t
#
#
#
#
# H
# e
# n
# r
# y
#
# F
# o
# n
# d
# a
#
#
#
# 1
# 9
# 5
# 7
#
#
#
# $
# 4
# .
# 3
# 6
# M
#
#
# T
# h
# e
#
# S
# i
# l
# e
# n
# c
# e
#
# o
# f
#
# t
# h
# e
#
# L
# a
# m
# b
# s
#
#
#
# J
# o
# n
# a
# t
# h
# a
# n
#
# D
# e
# m
# m
# e
#
#
#
# A
# n
# t
# h
# o
# n
# y
#
# H
# o
# p
# k
# i
# n
# s
#
#
#
#
# 1
# 9
# 9
# 1
#
#
#
# $
# 1
# 3
# 0
# .
# 7
# 4
# M
#
#
# I
# t
# '
# s
#
# a
#
# W
# o
# n
# d
# e
# r
# f
# u
# l
#
# L
# i
# f
# e
#
#
#
# F
# r
# a
# n
# k
#
# C
# a
# p
# r
# a
#
#
#
#
# J
# a
# m
# e
# s
#
# S
# t
# e
# w
# a
# r
# t
#
#
# 1
# 9
# 4
# 6
#
#
#
# $
# 5
# .
# 0
# 5
# M
#
#
# A
# m
# a
# d
# e
# u
# s
#
#
#
# M
# i
# l
# o
# s
#
# F
# o
# r
# m
# a
# n
#
#
#
# F
# .
#
# M
# u
# r
# r
# a
# y
#
# A
# b
# r
# a
# h
# a
# m
#
#
#
# 1
# 9
# 8
# 4
#
#
#
# $
# 5
# 1
# .
# 9
# 7
# M
#
#
# G
# l
# a
# d
# i
# a
# t
# o
# r
#
#
#
# R
# i
# d
# l
# e
# y
#
# S
# c
# o
# t
# t
#
#
#
#
# R
# u
# s
# s
# e
# l
# l
#
# C
# r
# o
# w
# e
#
#
# 2
# 0
# 0
# 0
#
#
#
# $
# 1
# 8
# 7
# .
# 7
# 1
# M
#
#
# T
# i
# t
# a
# n
# i
# c
#
#
#
# J
# a
# m
# e
# s
#
# C
# a
# m
# e
# r
# o
# n
#
#
#
# L
# e
# o
# n
# a
# r
# d
# o
#
# D
# i
# C
# a
# p
# r
# i
# o
#
#
#
# 1
# 9
# 9
# 7
#
#
#
# $
# 6
# 5
# 9
# .
# 3
# 3
# M
#
#
# S
# a
# v
# i
# n
# g
#
# P
# r
# i
# v
# a
# t
# e
#
# R
# y
# a
# n
#
#
#
# S
# t
# e
# v
# e
# n
#
# S
# p
# i
# e
# l
# b
# e
# r
# g
#
#
#
# T
# o
# m
#
# H
# a
# n
# k
# s
#
#
# 1
# 9
# 9
# 8
#
#
#
# $
# 2
# 1
# 6
# .
# 5
# 4
# M
#
#
# A
# n
#
# A
# m
# e
# r
# i
# c
# a
# n
#
# i
# n
#
# P
# a
# r
# i
# s
#
#
#
# V
# i
# n
# c
# e
# n
# t
# e
#
# M
# i
# n
# n
# e
# l
# l
# i
#
#
#
# G
# e
# n
# e
#
# K
# e
# l
# l
# y
#
#
#
# 1
# 9
# 5
# 1
#
#
#
# $
# 4
# .
# 5
# 0
# M
#
#
# T
# h
# e
#
# B
# e
# s
# t
#
# Y
# e
# a
# r
# s
#
# o
# f
#
# O
# u
# r
#
# L
# i
# v
# e
# s
#
#
#
# W
# i
# l
# l
# i
# a
# m
#
# W
# y
# l
# e
# r
#
#
#
# M
# y
# r
# n
# a
#
# L
# o
# y
#
#
#
# 1
# 9
# 4
# 6
#
#
#
# $
# 2
# 3
# .
# 6
# 5
# M
#
#
# A
#
# C
# l
# o
# c
# k
# w
# o
# r
# k
#
# O
# r
# a
# n
# g
# e
#
#
#
# S
# t
# a
# n
# l
# e
# y
#
# K
# u
# b
# r
# i
# c
# k
#
#
#
# M
# a
# l
# c
# o
# l
# m
#
# M
# c
# D
# o
# w
# e
# l
# l
#
#
#
# 1
# 9
# 7
# 1
#
#
#
# $
# 2
# 6
# .
# 5
# M
#
#
# D
# o
# c
# t
# o
# r
#
# Z
# h
# i
# v
# a
# g
# o
#
#
#
# D
# a
# v
# i
# d
#
# L
# e
# a
# n
#
#
#
# O
# m
# a
# r
#
# S
# h
# a
# r
# i
# f
#
#
#
# 1
# 9
# 6
# 5
#
#
#
# $
# 1
# 1
# 1
# .
# 7
# 2
# M
#
#
# J
# a
# w
# s
#
#
#
# S
# t
# e
# v
# e
# n
#
# S
# p
# i
# e
# l
# b
# e
# r
# g
#
#
#
# R
# o
# y
#
# S
# c
# h
# e
# i
# d
# e
# r
#
#
#
# 1
# 9
# 7
# 5
#
#
#
# $
# 2
# 6
# 0
# .
# 0
# 0
# M
#
#
# P
# a
# t
# t
# o
# n
#
#
#
# F
# r
# a
# n
# k
# l
# i
# n
#
# J
# .
#
# S
# c
# h
# a
# f
# f
# n
# e
# r
#
#
#
# G
# e
# o
# r
# g
# e
#
# C
# .
#
# S
# c
# o
# t
# t
#
#
#
# 1
# 9
# 7
# 0
#
#
#
# $
# 6
# 1
# .
# 7
# 0
# M
#
#
# A
#
# S
# t
# r
# e
# e
# t
# c
# a
# r
#
# N
# a
# m
# e
# d
#
# D
# e
# s
# i
# r
# e
#
#
#
# E
# l
# i
# a
#
# K
# a
# z
# a
# n
#
#
#
# V
# i
# v
# i
# e
# n
#
# L
# e
# i
# g
# h
#
#
#
# 1
# 9
# 5
# 1
#
#
#
# $
# 8
# .
# 0
# 0
# M
#
#
# R
# o
# c
# k
# y
#
#
#
# J
# o
# h
# n
#
# G
# .
#
# A
# v
# i
# l
# d
# s
# e
# n
#
#
#
# S
# y
# l
# v
# e
# s
# t
# e
# r
#
# S
# t
# a
# l
# l
# o
# n
# e
#
#
#
# 1
# 9
# 7
# 6
#
#
#
# $
# 1
# 1
# 7
# .
# 2
# 4
# M
#
#
# R
# a
# i
# d
# e
# r
# s
#
# o
# f
#
# t
# h
# e
#
# L
# o
# s
# t
#
# A
# r
# k
#
#
#
# S
# t
# e
# v
# e
# n
#
# S
# p
# i
# e
# l
# b
# e
# r
# g
#
#
#
# H
# a
# r
# r
# i
# s
# o
# n
#
# F
# o
# r
# d
#
#
#
# 1
# 9
# 8
# 1
#
#
#
# $
# 2
# 4
# 8
# .
# 1
# 6
# M
#
#
# U
# n
# f
# o
# r
# g
# i
# v
# e
# n
#
#
#
# C
# l
# i
# n
# t
#
# E
# a
# s
# t
# w
# o
# o
# d
#
#
#
# C
# l
# i
# n
# t
#
# E
# a
# s
# t
# w
# o
# o
# d
#
#
#
# 1
# 9
# 9
# 2
#
#
#
# $
# 1
# 0
# 1
# .
# 1
# 6
# M
#
#
# F
# r
# o
# m
#
# H
# e
# r
# e
#
# t
# o
#
# E
# t
# e
# r
# n
# i
# t
# y
#
#
#
# F
# r
# e
# d
#
# Z
# i
# n
# n
# e
# m
# a
# n
# n
#
#
#
# B
# u
# r
# t
#
# L
# a
# n
# c
# a
# s
# t
# e
# r
#
#
#
# 1
# 9
# 5
# 3
#
#
#
# $
# 3
# 0
# .
# 5
# 0
# M
#
#
# T
# h
# e
#
# L
# o
# r
# d
#
# o
# f
#
# t
# h
# e
#
# R
# i
# n
# g
# s
# -
#
# T
# h
# e
#
# R
# e
# t
# u
# r
# n
#
# o
# f
#
# t
# h
# e
#
# K
# i
# n
# g
#
#
#
# P
# e
# t
# e
# r
#
# J
# a
# c
# k
# s
# o
# n
#
#
# E
# l
# i
# j
# a
# h
#
# W
# o
# o
# d
#
#
# 2
# 0
# 0
# 3
#
#
#
# $
# 3
# 7
# 7
# .
# 8
# 5
# M
#
#
# A
# p
# o
# c
# a
# l
# y
# p
# s
# e
#
# N
# o
# w
#
#
#
# F
# r
# a
# n
# c
# i
# s
#
# F
# o
# r
# d
#
# C
# o
# p
# p
# o
# l
# a
#
#
#
# M
# a
# r
# t
# i
# n
#
# S
# h
# e
# e
# n
#
#
#
# 1
# 9
# 7
# 9
#
#
#
# $
# 8
# 3
# .
# 4
# 7
# M
#
#
# D
# a
# n
# c
# e
# s
#
# w
# i
# t
# h
#
# W
# o
# l
# v
# e
# s
#
#
#
# K
# e
# v
# i
# n
#
# C
# o
# s
# t
# n
# e
# r
#
#
#
# K
# e
# v
# i
# n
#
# C
# o
# s
# t
# n
# e
# r
#
#
#
# 1
# 9
# 9
# 0
#
#
#
# $
# 1
# 8
# 4
# .
# 2
# 1
# M
#
#
# O
# n
#
# t
# h
# e
#
# W
# a
# t
# e
# r
# f
# r
# o
# n
# t
#
#
#
# E
# l
# i
# a
#
# K
# a
# z
# a
# n
#
#
#
# M
# a
# r
# l
# o
# n
#
# B
# r
# a
# n
# d
# o
#
#
#
# 1
# 9
# 5
# 4
#
#
#
# $
# 9
# .
# 6
# 0
# M
#
#
# B
# e
# n
# -
# H
# u
# r
#
#
#
# W
# i
# l
# l
# i
# a
# m
#
# W
# y
# l
# e
# r
#
#
#
# C
# h
# a
# r
# l
# t
# o
# n
#
# H
# e
# s
# t
# o
# n
#
#
#
# 1
# 9
# 5
# 9
#
#
#
# $
# 7
# 4
# .
# 7
# 0
# M
#
#
# S
# i
# n
# g
# i
# n
# '
#
# i
# n
#
# t
# h
# e
#
# R
# a
# i
# n
#
#
#
# S
# t
# a
# n
# l
# e
# y
#
# D
# o
# n
# e
# n
#
#
#
# G
# e
# n
# e
#
# K
# e
# l
# l
# y
#
#
#
# 1
# 9
# 5
# 2
#
#
#
# $
# 8
# .
# 8
# 2
# M
#
#
# T
# h
# e
#
# B
# r
# i
# d
# g
# e
#
# o
# n
#
# t
# h
# e
#
# R
# i
# v
# e
# r
#
# K
# w
# a
# i
#
#
#
# D
# a
# v
# i
# d
#
# L
# e
# a
# n
#
#
#
# W
# i
# l
# l
# i
# a
# m
#
# H
# o
# l
# d
# e
# n
#
#
#
# 1
# 9
# 5
# 7
#
#
#
# $
# 4
# 4
# .
# 9
# 1
# M
#
#
# C
# h
# i
# n
# a
# t
# o
# w
# n
#
#
#
# R
# o
# m
# a
# n
#
# P
# o
# l
# a
# n
# s
# k
# i
#
#
#
# J
# a
# c
# k
#
# N
# i
# c
# h
# o
# l
# s
# o
# n
#
#
#
# 1
# 9
# 7
# 4
#
#
#
# $
# 2
# 9
# .
# 2
# 0
# M
#
#
# E
# .
# T
# .
#
# t
# h
# e
#
# E
# x
# t
# r
# a
# -
# T
# e
# r
# r
# e
# s
# t
# r
# i
# a
# l
#
#
#
# S
# t
# e
# v
# e
# n
#
# S
# p
# i
# e
# l
# b
# e
# r
# g
#
#
#
# H
# e
# n
# r
# y
#
# T
# h
# o
# m
# a
# s
#
#
#
# 1
# 9
# 8
# 2
#
#
#
# $
# 4
# 3
# 5
# .
# 1
# 1
# M
#
#
# A
#
# S
# p
# a
# c
# e
#
# O
# d
# y
# s
# s
# e
# y
#
#
#
# S
# t
# a
# n
# l
# e
# y
#
# K
# u
# b
# r
# i
# c
# k
#
#
#
# K
# e
# i
# r
#
# D
# u
# l
# l
# e
# a
#
#
#
# 1
# 9
# 6
# 8
#
#
#
# $
# 5
# 6
# .
# 9
# 5
# M
#
#
# W
# e
# s
# t
#
# S
# i
# d
# e
#
# S
# t
# o
# r
# y
#
#
#
# J
# e
# r
# o
# m
# e
#
# R
# o
# b
# b
# i
# n
# s
#
#
#
# N
# a
# t
# a
# l
# i
# e
#
# W
# o
# o
# d
#
#
#
# 1
# 9
# 6
# 1
#
#
#
# $
# 4
# 3
# .
# 6
# 6
# M
#
#
# T
# h
# e
#
# S
# o
# u
# n
# d
#
# o
# f
#
# M
# u
# s
# i
# c
#
#
#
# R
# o
# b
# e
# r
# t
#
# W
# i
# s
# e
#
#
#
# J
# u
# l
# i
# e
#
# A
# n
# d
# r
# e
# w
# s
#
#
#
# 1
# 9
# 6
# 5
#
#
#
# $
# 1
# 6
# 3
# .
# 2
# 1
# M
#
#
# P
# s
# y
# c
# h
# o
#
#
#
# A
# l
# f
# r
# e
# d
#
# H
# i
# t
# c
# h
# c
# o
# c
# k
#
#
#
# A
# n
# t
# h
# o
# n
# y
#
# P
# e
# r
# k
# i
# n
# s
#
#
#
# 1
# 9
# 6
# 0
#
#
#
# $
# 3
# 2
# .
# 0
# 0
# M
#
#
# L
# a
# w
# r
# e
# n
# c
# e
#
# o
# f
#
# A
# r
# a
# b
# i
# a
#
#
#
# D
# a
# v
# i
# d
#
# L
# e
# a
# n
#
#
#
# P
# e
# t
# e
# r
#
# O
# '
# T
# o
# o
# l
# e
#
#
#
# 1
# 9
# 6
# 2
#
#
#
# $
# 4
# 4
# .
# 8
# 2
# M
#
#
# O
# n
# e
#
# F
# l
# e
# w
#
# O
# v
# e
# r
#
# t
# h
# e
#
# C
# u
# c
# k
# o
# o
# '
# s
#
# N
# e
# s
# t
#
#
#
# M
# i
# l
# o
# s
#
# F
# o
# r
# m
# a
# n
#
#
#
# J
# a
# c
# k
#
# N
# i
# c
# h
# o
# l
# s
# o
# n
#
#
#
# 1
# 9
# 7
# 5
#
#
#
# $
# 1
# 1
# 2
# .
# 0
# 0
# M
#
#
# G
# o
# n
# e
#
# w
# i
# t
# h
#
# t
# h
# e
#
# W
# i
# n
# d
#
#
#
# V
# i
# c
# t
# o
# r
#
# F
# l
# e
# m
# i
# n
# g
#
#
#
# C
# l
# a
# r
# k
#
# G
# a
# b
# l
# e
#
#
#
# 1
# 9
# 3
# 9
#
#
#
# $
# 1
# 9
# 8
# .
# 6
# 8
# M
#
#
# C
# i
# t
# i
# z
# e
# n
#
# K
# a
# n
# e
#
#
#
# O
# r
# s
# o
# n
#
# W
# e
# l
# l
# e
# s
#
#
#
# O
# r
# s
# o
# n
#
# W
# e
# l
# l
# e
# s
#
#
# 1
# 9
# 4
# 1
#
#
#
# $
# 1
# .
# 5
# 9
# M
#
#
# C
# a
# s
# a
# b
# l
# a
# n
# c
# a
#
#
#
# M
# i
# c
# h
# a
# e
# l
#
# C
# u
# r
# t
# i
# z
#
#
#
# H
# u
# m
# p
# h
# r
# e
# y
#
# B
# o
# g
# a
# r
# t
#
#
#
# 1
# 9
# 4
# 2
#
#
#
# $
# 1
# .
# 0
# 2
# M
#
#
# R
# a
# g
# i
# n
# g
#
# B
# u
# l
# l
#
#
#
# M
# a
# r
# t
# i
# n
#
# S
# c
# o
# r
# s
# e
# s
# e
#
#
#
# R
# o
# b
# e
# r
# t
#
# D
# e
#
# N
# i
# r
# o
#
#
#
# 1
# 9
# 8
# 0
#
#
#
# $
# 2
# 3
# .
# 3
# 8
# M
#
#
# T
# h
# e
#
# G
# o
# o
# d
# ,
#
# t
# h
# e
#
# B
# a
# d
#
# a
# n
# d
#
# t
# h
# e
#
# U
# g
# l
# y
#
#
#
# S
# e
# r
# g
# i
# o
#
# L
# e
# o
# n
# e
#
#
#
# C
# l
# i
# n
# t
#
# E
# a
# s
# t
# w
# o
# o
# d
#
#
# 1
# 9
# 6
# 6
#
#
#
# $
# 6
# .
# 1
# 0
# M
#
#
# P
# l
# a
# t
# o
# o
# n
#
#
#
# O
# l
# i
# v
# e
# r
#
# S
# t
# o
# n
# e
#
#
#
# C
# h
# a
# r
# l
# i
# e
#
# S
# h
# e
# e
# n
#
#
# 1
# 9
# 8
# 6
#
#
#
# $
# 1
# 3
# 8
# .
# 5
# 3
# M
#
#
# H
# i
# g
# h
#
# N
# o
# o
# n
#
#
#
# F
# r
# e
# d
#
# Z
# i
# n
# n
# e
# m
# a
# n
# n
#
#
#
# G
# a
# r
# y
#
# C
# o
# o
# p
# e
# r
#
#
#
# 1
# 9
# 5
# 2
#
#
#
# $
# 9
# .
# 4
# 5
# M
#
#
# J
# u
# r
# a
# s
# s
# i
# c
#
# P
# a
# r
# k
#
#
#
# S
# t
# e
# v
# e
# n
#
# S
# p
# i
# e
# l
# b
# e
# r
# g
#
#
#
# S
# a
# m
#
# N
# e
# i
# l
# l
#
#
# 1
# 9
# 9
# 3
#
#
#
# $
# 4
# 0
# 2
# .
# 4
# 5
# M

# %%
with open("movie_Information.txt",'r') as f:
    movies = f.readlines()
#     print(movies)
    with open ("Actors_Information.txt",'w') as m:
        for movie in movies:
#             print((movie))
            actor_name = movie.split(":")
            print((actor_name))

# %%
with open ("Actors_Information.txt",'r') as m:
    info = m.read().splitlines()
    count = 0
    for i in range(0,len(info)):
        actor, movie = info[i].split(":")
        if (actor.count("Tom Hanks")) == True:
            count+=1
    print(count)
# Out:
# 4

# %%
verse = "If you can keep your head when all about you\nAre losing theirs and blaming it on you,\nIf you can trust yourself when all men doubt you,\nBut make allowance for their doubting too;\nIf you can wait and not be tired by waiting,\nOr being lied about, don’t deal in lies,\nOr being hated, don’t give way to hating,\nAnd yet don’t look too good, nor talk too wise:"
print(len(verse))
# Out:
# 354

# %%
# Out:
# ----bee-----

# %%
1/7
# Out:
# 0.14285714285714285

# %%
hl = 0.14285714285714285
print("{:.4f}".format(hl))
# Out:
# 0.1429

# %%
sum = 12
print(sum)
# Out:
# 12

# %%
m = (1/3 + 1/3)

# %%
nm = 1400000000000000
print(type(nm))
# Out:
# <class 'int'>

# %%
string = "hello"
print(repr(string))
# Out:
# 'hello'

# %%
verse = "If you can keep your head when all about you\n  Are losing theirs and blaming it on you,\nIf you can trust yourself when all men doubt you,\n  But make allowance for their doubting too;\nIf you can wait and not be tired by waiting,\n  Or being lied about, don’t deal in lies,\nOr being hated, don’t give way to hating,\n  And yet don’t look too good, nor talk too wise:"
print(verse.rindex("and"))
# Out:
# 199
